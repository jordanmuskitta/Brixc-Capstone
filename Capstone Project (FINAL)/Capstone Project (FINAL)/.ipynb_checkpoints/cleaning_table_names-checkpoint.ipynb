# %%
import re

# %%
pattern = '`pixc`.`'

# String manipulation for table names: 

string = '`pixc`.`AccessTokens`, `pixc`.`AccountCredits`, `pixc`.`AddonPrices`, `pixc`.`AgreementDeliveries`, `pixc`.`AltiusActions`, `pixc`.`Altiuses`, `pixc`.`AltiusImageMetas`, `pixc`.`AltiusImages`, `pixc`.`AltiusItems`, `pixc`.`AltiusTemplates`, `pixc`.`AltiusUpdates`, `pixc`.`AnalyzerActions`, `pixc`.`AnalyzerImageMetas`, `pixc`.`AnalyzerItems`, `pixc`.`AnalyzerProducts`, `pixc`.`AnalyzerReports`, `pixc`.`Analyzers`, `pixc`.`ApiWebhooks`, `pixc`.`ApiWebhookTransactions`, `pixc`.`Archives`, `pixc`.`CardAddAttempts`, `pixc`.`CloudAccounts`, `pixc`.`CloudFiles`, `pixc`.`CloudOrders`, `pixc`.`CreditBatches`, `pixc`.`CreditPackagePaymentSubscriptionTypes`, `pixc`.`CreditPackagePrices`, `pixc`.`CreditPackages`, `pixc`.`CreditPackageSubscriptionTypes`, `pixc`.`CreditTransactions`, `pixc`.`Currencies`, `pixc`.`CustomerAffiliates`, `pixc`.`CustomerAffiliateTransactions`, `pixc`.`CustomerBonuses`, `pixc`.`CustomerCloudAccounts`, `pixc`.`CustomereCommercePlatforms`, `pixc`.`CustomerLeads`, `pixc`.`CustomerLocks`, `pixc`.`CustomerMigrations`, `pixc`.`CustomerReferralAccepted`, `pixc`.`CustomerReferrals`, `pixc`.`Customers`, `pixc`.`CustomerShopAccounts`, `pixc`.`CustomerShopAccountWebhooks`, `pixc`.`CustomerTemplates`, `pixc`.`DeliveryResults`, `pixc`.`DownloadDeliveries`, `pixc`.`Downloads`, `pixc`.`eCommercePlatforms`, `pixc`.`FacebookLogins`, `pixc`.`FakeWebhooks`, `pixc`.`FeaturePrices`, `pixc`.`GoogleLogins`, `pixc`.`Invitations`, `pixc`.`Invoices`, `pixc`.`KitConversations`, `pixc`.`LegacyPromo`, `pixc`.`LinkedInLogins`, `pixc`.`lk_Roles`, `pixc`.`lk_Status`, `pixc`.`lk_Tags`, `pixc`.`LogErrors`, `pixc`.`LogExceptions`, `pixc`.`LogInfos`, `pixc`.`LogRequests`, `pixc`.`LogServices`, `pixc`.`min_accounts`, `pixc`.`min_captions`, `pixc`.`min_files`, `pixc`.`min_general_data`, `pixc`.`min_options`, `pixc`.`min_orders`, `pixc`.`min_packages`, `pixc`.`min_plugins`, `pixc`.`min_posts`, `pixc`.`min_proxies`, `pixc`.`min_themes`, `pixc`.`min_users`, `pixc`.`Notifications`, `pixc`.`Offers`, `pixc`.`OrderAssignments`, `pixc`.`OrderImageAddons`, `pixc`.`OrderImageAgreementExtensionTokens`, `pixc`.`OrderImageAgreements`, `pixc`.`OrderImageAssignmentArchives`, `pixc`.`OrderImageAssignments`, `pixc`.`OrderImageDeliveryRejected`, `pixc`.`OrderImagePrices`, `pixc`.`OrderImageQaAgreements`, `pixc`.`OrderImages`, `pixc`.`OrderImageSkipped`, `pixc`.`OrderImageSkippedQa`, `pixc`.`OrderImageTags`, `pixc`.`OrderMails`, `pixc`.`OrderMigrations`, `pixc`.`OrderNotes`, `pixc`.`OrderQaAssignments`, `pixc`.`Orders`, `pixc`.`PasswordResets`, `pixc`.`PaymentAccounts`, `pixc`.`PaymentAttempts`, `pixc`.`PaymentMethods`, `pixc`.`PaymentProviders`, `pixc`.`PaymentSubscriptions`, `pixc`.`PaymentSubscriptionTypeFeatureRefers`, `pixc`.`PaymentSubscriptionTypeFeatures`, `pixc`.`PaymentSubscriptionTypePrices`, `pixc`.`PaymentSubscriptionTypes`, `pixc`.`PaymentTransactionBonuses`, `pixc`.`PaymentTransactionCredits`, `pixc`.`PaymentTransactionItems`, `pixc`.`PaymentTransactions`, `pixc`.`PaymentTransactionsMoney`, `pixc`.`Previews`, `pixc`.`PromoCodeCreditPackages`, `pixc`.`PromoCodes`, `pixc`.`PromoterCustomers`, `pixc`.`PromoterCustomerTransactions`, `pixc`.`Promoters`, `pixc`.`RememberMeLogins`, `pixc`.`RemovebgActions`, `pixc`.`RemovebgImages`, `pixc`.`RemovebgProducts`, `pixc`.`RemovebgResults`, `pixc`.`Removebgs`, `pixc`.`RemovebgTemplates`, `pixc`.`RenameBatches`, `pixc`.`RenameBatchItems`, `pixc`.`RenamePeers`, `pixc`.`RenamePeerTypes`, `pixc`.`RenameRules`, `pixc`.`RenameRuleTypes`, `pixc`.`Renames`, `pixc`.`ReportImages`, `pixc`.`ReportPages`, `pixc`.`Reports`, `pixc`.`ResizeActions`, `pixc`.`ResizeImages`, `pixc`.`ResizeItemInvoices`, `pixc`.`ResizeItems`, `pixc`.`ResizeLogs`, `pixc`.`Resizes`, `pixc`.`ResizeTemplates`, `pixc`.`ResizeUpdates`, `pixc`.`Settings`, `pixc`.`ShopAccounts`, `pixc`.`ShopFiles`, `pixc`.`ShopProductImages`, `pixc`.`ShopProducts`, `pixc`.`ShopRemoteFiles`, `pixc`.`SquareImages`, `pixc`.`Squares`, `pixc`.`SubscriptionQuotas`, `pixc`.`Subscriptions`, `pixc`.`SubscriptionTypeFeatureRefers`, `pixc`.`SubscriptionTypeFeatures`, `pixc`.`SubscriptionTypePrices`, `pixc`.`SubscriptionTypes`, `pixc`.`Teams`, `pixc`.`TimeMachine`, `pixc`.`TrackArchives`, `pixc`.`TrackEvents`, `pixc`.`TrackPages`, `pixc`.`TrackProfiles`, `pixc`.`UserAvailability`, `pixc`.`UserAvailabilityLogs`, `pixc`.`Users`, `pixc`.`Users2Tags`, `pixc`.`UserTags`, `pixc`.`wp_avhec_category_groups`, `pixc`.`wp_commentmeta`, `pixc`.`wp_comments`, `pixc`.`wp_links`, `pixc`.`wp_maxbuttons_collections`, `pixc`.`wp_maxbuttons_collections_trans`, `pixc`.`wp_maxbuttonsv3`, `pixc`.`wp_medium_migration`, `pixc`.`wp_options`, `pixc`.`wp_postmeta`, `pixc`.`wp_posts`, `pixc`.`wp_redirection_404`, `pixc`.`wp_redirection_groups`, `pixc`.`wp_redirection_items`, `pixc`.`wp_redirection_logs`, `pixc`.`wp_rg_form`, `pixc`.`wp_rg_form_meta`, `pixc`.`wp_rg_form_view`, `pixc`.`wp_rg_incomplete_submissions`, `pixc`.`wp_rg_lead`, `pixc`.`wp_rg_lead_detail`, `pixc`.`wp_rg_lead_detail_long`, `pixc`.`wp_rg_lead_meta`, `pixc`.`wp_rg_lead_notes`, `pixc`.`wp_term_relationships`, `pixc`.`wp_term_taxonomy`, `pixc`.`wp_termmeta`, `pixc`.`wp_terms`, `pixc`.`wp_usermeta`, `pixc`.`wp_users`, `pixc`.`wp_wc_download_log`, `pixc`.`wp_wc_webhooks`, `pixc`.`wp_woocommerce_api_keys`, `pixc`.`wp_woocommerce_attribute_taxonomies`, `pixc`.`wp_woocommerce_downloadable_product_permissions`, `pixc`.`wp_woocommerce_log`, `pixc`.`wp_woocommerce_order_itemmeta`, `pixc`.`wp_woocommerce_order_items`, `pixc`.`wp_woocommerce_payment_tokenmeta`, `pixc`.`wp_woocommerce_payment_tokens`, `pixc`.`wp_woocommerce_sessions`, `pixc`.`wp_woocommerce_shipping_zone_locations`, `pixc`.`wp_woocommerce_shipping_zone_methods`, `pixc`.`wp_woocommerce_shipping_zones`, `pixc`.`wp_woocommerce_tax_rate_locations`, `pixc`.`wp_woocommerce_tax_rates`, `pixc`.`wp_wplnst_scans`, `pixc`.`wp_wplnst_scans_objects`, `pixc`.`wp_wplnst_urls`, `pixc`.`wp_wplnst_urls_locations`, `pixc`.`wp_wplnst_urls_locations_att`, `pixc`.`wp_wplnst_urls_status`, `pixc`.`wp_yoast_indexable`, `pixc`.`wp_yoast_indexable_hierarchy`, `pixc`.`wp_yoast_migrations`, `pixc`.`wp_yoast_primary_term`, `pixc`.`wp_yoast_seo_links`, `pixc`.`wp_yoast_seo_meta`'

split_string = re.split(pattern, string)

# %%
split_string
# Out:
# ['',
#  'AccessTokens`, ',
#  'AccountCredits`, ',
#  'AddonPrices`, ',
#  'AgreementDeliveries`, ',
#  'AltiusActions`, ',
#  'Altiuses`, ',
#  'AltiusImageMetas`, ',
#  'AltiusImages`, ',
#  'AltiusItems`, ',
#  'AltiusTemplates`, ',
#  'AltiusUpdates`, ',
#  'AnalyzerActions`, ',
#  'AnalyzerImageMetas`, ',
#  'AnalyzerItems`, ',
#  'AnalyzerProducts`, ',
#  'AnalyzerReports`, ',
#  'Analyzers`, ',
#  'ApiWebhooks`, ',
#  'ApiWebhookTransactions`, ',
#  'Archives`, ',
#  'CardAddAttempts`, ',
#  'CloudAccounts`, ',
#  'CloudFiles`, ',
#  'CloudOrders`, ',
#  'CreditBatches`, ',
#  'CreditPackagePaymentSubscriptionTypes`, ',
#  'CreditPackagePrices`, ',
#  'CreditPackages`, ',
#  'CreditPackageSubscriptionTypes`, ',
#  'CreditTransactions`, ',
#  'Currencies`, ',
#  'CustomerAffiliates`, ',
#  'CustomerAffiliateTransactions`, ',
#  'CustomerBonuses`, ',
#  'CustomerCloudAccounts`, ',
#  'CustomereCommercePlatforms`, ',
#  'CustomerLeads`, ',
#  'CustomerLocks`, ',
# ...

# %%
new_list = []

#Strip and add to new list:

for i in split_string: 
    new_list.append(i.strip('`, '))

# %%
new_list
# Out:
# ['',
#  'AccessTokens',
#  'AccountCredits',
#  'AddonPrices',
#  'AgreementDeliveries',
#  'AltiusActions',
#  'Altiuses',
#  'AltiusImageMetas',
#  'AltiusImages',
#  'AltiusItems',
#  'AltiusTemplates',
#  'AltiusUpdates',
#  'AnalyzerActions',
#  'AnalyzerImageMetas',
#  'AnalyzerItems',
#  'AnalyzerProducts',
#  'AnalyzerReports',
#  'Analyzers',
#  'ApiWebhooks',
#  'ApiWebhookTransactions',
#  'Archives',
#  'CardAddAttempts',
#  'CloudAccounts',
#  'CloudFiles',
#  'CloudOrders',
#  'CreditBatches',
#  'CreditPackagePaymentSubscriptionTypes',
#  'CreditPackagePrices',
#  'CreditPackages',
#  'CreditPackageSubscriptionTypes',
#  'CreditTransactions',
#  'Currencies',
#  'CustomerAffiliates',
#  'CustomerAffiliateTransactions',
#  'CustomerBonuses',
#  'CustomerCloudAccounts',
#  'CustomereCommercePlatforms',
#  'CustomerLeads',
#  'CustomerLocks',
#  'CustomerMigrations',
#  'CustomerReferralAccepted',
#  'CustomerReferrals',
#  'Customers',
#  'CustomerShopAccounts',
# ...

# %%
# String to one line, just place the information between quotation marks

string_one = '''id int(11) AI PK 
oid varchar(255) 
meta text 
createdAt datetime 
updatedAt datetime
'''

# %%
new_string_one = string_one.replace('\n',",")

# %%
new_string_one
# Out:
# 'id int(11) AI PK ,oid varchar(255) ,meta text ,createdAt datetime ,updatedAt datetime,'
